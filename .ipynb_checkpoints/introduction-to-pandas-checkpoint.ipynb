# %%
import pandas as pd

# %%
#2 main datatypes
carbrands=pd.Series(["BMW","Toyota","Honda"])

# %%
carbrands
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
#series= 1-dimensional

# %%
colours=pd.Series(["Red","Blue","White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#dataframe= 1-dimensional
car_data=pd.DataFrame({"car make":carbrands, "Colour":colours })
car_data
# Out:
#   car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
#Import data
house_features=pd.read_csv("housefeatures.csv")

# %%
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      yes
# 1    5950000  7020         3          1        1      yes        no      yes
# 2    5950000  6540         3          1        1      yes       yes      yes
# 3    5950000  7231         3          1        2      yes       yes      yes
# 4    5950000  6254         4          2        1      yes        no      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      yes
# 97   4830000  4160         3          1        3      yes        no       no
# 98   4830000  6040         3          1        1      yes        no       no
# 99   4830000  6862         3          1        2      yes        no       no
# 100  4830000  4815         2          1        1      yes        no       no
#
# ...

# %%
#Exporting a dataframe
house_features.to_csv("Exported-house-features.csv", index=False)

# %%
exported_house_features=pd.read_csv("Exported-house-features.csv")
exported_house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      yes
# 1    5950000  7020         3          1        1      yes        no      yes
# 2    5950000  6540         3          1        1      yes       yes      yes
# 3    5950000  7231         3          1        2      yes       yes      yes
# 4    5950000  6254         4          2        1      yes        no      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      yes
# 97   4830000  4160         3          1        3      yes        no       no
# 98   4830000  6040         3          1        1      yes        no       no
# 99   4830000  6862         3          1        2      yes        no       no
# 100  4830000  4815         2          1        1      yes        no       no
#
# ...

# %% [markdown]
# ## Describe data

# %%
#Attribute
house_features.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
house_features.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
house_columns= house_features.columns
house_columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
house_features.index
# Out:
# RangeIndex(start=0, stop=101, step=1)

# %%
house_features.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  1.010000e+02    101.000000  101.000000  101.000000  101.000000
# mean   5.351292e+06   6063.831683    3.168317    1.346535    1.801980
# std    3.625878e+05   2246.334779    0.617565    0.518375    0.860463
# min    4.830000e+06   2800.000000    2.000000    1.000000    1.000000
# 25%    5.033000e+06   4640.000000    3.000000    1.000000    1.000000
# 50%    5.250000e+06   5948.000000    3.000000    1.000000    2.000000
# 75%    5.600000e+06   6862.000000    3.000000    2.000000    2.000000
# max    5.950000e+06  15600.000000    5.000000    3.000000    4.000000
#
#           parking
# count  101.000000
# mean     0.732673
# std      0.870530
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      2.000000
# max      2.000000

# %%
house_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             101 non-null    int64
#  1   area              101 non-null    int64
#  2   bedrooms          101 non-null    int64
#  3   bathrooms         101 non-null    int64
#  4   stories           101 non-null    int64
#  5   mainroad          101 non-null    object
#  6   guestroom         101 non-null    object
#  7   basement          101 non-null    object
#  8   hotwaterheating   101 non-null    object
#  9   airconditioning   101 non-null    object
#  10  parking           101 non-null    int64
#  11  prefarea          101 non-null    object
#  12  furnishingstatus  101 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 10.4+ KB

# %%
house_features.mean()
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_6272/2833440622.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   house_features.mean()
# price        5.351292e+06
# area         6.063832e+03
# bedrooms     3.168317e+00
# bathrooms    1.346535e+00
# stories      1.801980e+00
# parking      7.326733e-01
# dtype: float64

# %%
house_features.sum()
# Out:
# price                                                       540480500
# area                                                           612447
# bedrooms                                                          320
# bathrooms                                                         136
# stories                                                           182
# mainroad            yesyesyesyesyesyesyesyesyesyesyesyesyesyesyesy...
# guestroom           nonoyesyesnonononononoyesnoyesyesnonononononon...
# basement            yesyesyesyesyesnononoyesnononoyesnononoyesnono...
# hotwaterheating     nonononononononononononononononononononononono...
# airconditioning     yesyesnoyesnononoyesnoyesyesnononoyesyesnoyesy...
# parking                                                            74
# prefarea            yesyesyesyesyesnononoyesnonoyesnonononoyesnono...
# furnishingstatus    furnishedsemi-furnishedfurnishedsemi-furnished...
# dtype: object

# %%
house_features["price"].sum()
# Out:
# 540480500

# %%
len(house_features)
# Out:
# 101

# %% [markdown]
# ## Viewing and selecting data

# %%
house_features.head()
# Out:
#      price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  5950000  6420         3          1        1      yes        no      yes
# 1  5950000  7020         3          1        1      yes        no      yes
# 2  5950000  6540         3          1        1      yes       yes      yes
# 3  5950000  7231         3          1        2      yes       yes      yes
# 4  5950000  6254         4          2        1      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        0      yes        furnished
# 1              no             yes        2      yes   semi-furnished
# 2              no              no        2      yes        furnished
# 3              no             yes        0      yes   semi-furnished
# 4              no              no        1      yes   semi-furnished

# %%
house_features.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 96   4865000  4350         2          1        1      yes        no      yes
# 97   4830000  4160         3          1        3      yes        no       no
# 98   4830000  6040         3          1        1      yes        no       no
# 99   4830000  6862         3          1        2      yes        no       no
# 100  4830000  4815         2          1        1      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 96               no              no        0       no      unfurnished
# 97               no              no        0       no      unfurnished
# 98               no              no        2      yes   semi-furnished
# 99               no             yes        2      yes        furnished
# 100              no             yes        0      yes   semi-furnished

# %%
#.loc and .iloc
animal = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'],index=[0,3,9,8,3])

# %%
animal
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animal.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animal.loc[9]
# Out:
# 'bird'

# %%
animal.iloc[3]
# Out:
# 'panda'

# %%
animal.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
house_features[house_features['furnishingstatus']=='unfurnished']
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 8   5880000  7160         3          1        1      yes        no      yes
# 9   5880000  6500         3          2        3      yes        no       no
# 12  5866000  4800         3          1        1      yes       yes      yes
# 15  5810000  4800         3          1        3      yes        no       no
# 17  5775000  6000         3          2        4      yes        no       no
# 18  5740000  5400         4          2        2      yes        no       no
# 22  5740000  5800         3          2        4      yes        no       no
# 25  5600000  4800         5          2        3       no        no      yes
# 32  5600000  5136         3          1        2      yes       yes      yes
# 47  5383000  6450         3          2        1      yes       yes      yes
# 48  5320000  7800         3          1        1      yes        no      yes
# ...

# %%
pd.crosstab(house_features['furnishingstatus'], house_features['price'])
# Out:
# price             4830000  4865000  4893000  4900000  4907000  4935000  \
# furnishingstatus
# furnished               1        0        0        1        1        0
# semi-furnished          2        0        2       10        0        1
# unfurnished             1        1        0        1        0        0
#
# price             4956000  4970000  5005000  5033000  ...  5652500  5740000  \
# furnishingstatus                                      ...
# furnished               0        0        0        0  ...        0        1
# semi-furnished          1        2        1        1  ...        1        2
# unfurnished             0        0        0        0  ...        0        2
#
# price             5775000  5803000  5810000  5866000  5873000  5880000  \
# furnishingstatus
# furnished               0        0        0        0        1        0
# semi-furnished          0        1        2        0        1        0
# ...

# %%
#Groupby
house_features.groupby(['furnishingstatus']).mean()
# Out:
#                          price         area  bedrooms  bathrooms   stories  \
# furnishingstatus
# furnished         5.423542e+06  6304.333333  3.291667   1.291667  1.958333
# semi-furnished    5.296405e+06  6121.500000  3.137931   1.362069  1.655172
# unfurnished       5.427579e+06  5584.000000  3.105263   1.368421  2.052632
#
#                    parking
# furnishingstatus
# furnished         0.875000
# semi-furnished    0.758621
# unfurnished       0.473684

# %%
house_features["price"].plot()
# Out:
# <AxesSubplot:>

# %%
house_features.groupby(['price']).mean()
# Out:
#                  area  bedrooms  bathrooms   stories   parking
# price
# 4830000   5469.250000  2.750000   1.000000  1.750000  1.000000
# 4865000   4350.000000  2.000000   1.000000  1.000000  0.000000
# 4893000   4207.500000  4.000000   2.000000  1.500000  1.000000
# 4900000   5436.750000  2.916667   1.000000  1.583333  0.583333
# 4907000   4200.000000  3.000000   1.000000  2.000000  1.000000
# 4935000   5948.000000  3.000000   1.000000  2.000000  0.000000
# 4956000   2800.000000  3.000000   2.000000  2.000000  1.000000
# 4970000   6048.000000  3.500000   2.000000  1.500000  1.000000
# 5005000   8150.000000  3.000000   2.000000  1.000000  0.000000
# 5033000   4800.000000  2.000000   1.000000  1.000000  0.000000
# 5040000   7110.000000  3.000000   1.000000  1.500000  0.500000
# 5075000   5720.000000  2.000000   1.000000  2.000000  0.000000
# 5110000   5877.500000  2.750000   1.250000  1.750000  0.000000
# 5145000   5695.000000  3.000000   1.000000  1.500000  0.500000
# ...

# %%
house_features['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating data

# %%
house_features['basement'].str.upper()
# Out:
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4      YES
#       ...
# 96     YES
# 97      NO
# 98      NO
# 99      NO
# 100     NO
# Name: basement, Length: 101, dtype: object

# %%
house_features['basement'] = house_features['basement'].str.upper()

# %%
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      YES
# 1    5950000  7020         3          1        1      yes        no      YES
# 2    5950000  6540         3          1        1      yes       yes      YES
# 3    5950000  7231         3          1        2      yes       yes      YES
# 4    5950000  6254         4          2        1      yes        no      YES
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      YES
# 97   4830000  4160         3          1        3      yes        no       NO
# 98   4830000  6040         3          1        1      yes        no       NO
# 99   4830000  6862         3          1        2      yes        no       NO
# 100  4830000  4815         2          1        1      yes        no       NO
#
# ...

# %%
#Column from series
balcony= pd.Series([1,2,3,4,5])

#New cloumn named balcony
house_features["Balcony"] = balcony
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      YES
# 1    5950000  7020         3          1        1      yes        no      YES
# 2    5950000  6540         3          1        1      yes       yes      YES
# 3    5950000  7231         3          1        2      yes       yes      YES
# 4    5950000  6254         4          2        1      yes        no      YES
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      YES
# 97   4830000  4160         3          1        3      yes        no       NO
# 98   4830000  6040         3          1        1      yes        no       NO
# 99   4830000  6862         3          1        2      yes        no       NO
# 100  4830000  4815         2          1        1      yes        no       NO
#
# ...

# %%
house_features["Balcony"].fillna(0, inplace=True)

# %%
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      YES
# 1    5950000  7020         3          1        1      yes        no      YES
# 2    5950000  6540         3          1        1      yes       yes      YES
# 3    5950000  7231         3          1        2      yes       yes      YES
# 4    5950000  6254         4          2        1      yes        no      YES
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      YES
# 97   4830000  4160         3          1        3      yes        no       NO
# 98   4830000  6040         3          1        1      yes        no       NO
# 99   4830000  6862         3          1        2      yes        no       NO
# 100  4830000  4815         2          1        1      yes        no       NO
#
# ...

# %%
#Column from other coulmns
house_features['p*s']= house_features['parking']*house_features['stories']
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      YES
# 1    5950000  7020         3          1        1      yes        no      YES
# 2    5950000  6540         3          1        1      yes       yes      YES
# 3    5950000  7231         3          1        2      yes       yes      YES
# 4    5950000  6254         4          2        1      yes        no      YES
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      YES
# 97   4830000  4160         3          1        3      yes        no       NO
# 98   4830000  6040         3          1        1      yes        no       NO
# 99   4830000  6862         3          1        2      yes        no       NO
# 100  4830000  4815         2          1        1      yes        no       NO
#
# ...

# %%
#Create a column from single values
house_features["Covid friendly"]= "Yes"
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      YES
# 1    5950000  7020         3          1        1      yes        no      YES
# 2    5950000  6540         3          1        1      yes       yes      YES
# 3    5950000  7231         3          1        2      yes       yes      YES
# 4    5950000  6254         4          2        1      yes        no      YES
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      YES
# 97   4830000  4160         3          1        3      yes        no       NO
# 98   4830000  6040         3          1        1      yes        no       NO
# 99   4830000  6862         3          1        2      yes        no       NO
# 100  4830000  4815         2          1        1      yes        no       NO
#
# ...

# %%
house_features = house_features.drop("p*s", axis=1)

# %%
house_features
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5950000  6420         3          1        1      yes        no      YES
# 1    5950000  7020         3          1        1      yes        no      YES
# 2    5950000  6540         3          1        1      yes       yes      YES
# 3    5950000  7231         3          1        2      yes       yes      YES
# 4    5950000  6254         4          2        1      yes        no      YES
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 96   4865000  4350         2          1        1      yes        no      YES
# 97   4830000  4160         3          1        3      yes        no       NO
# 98   4830000  6040         3          1        1      yes        no       NO
# 99   4830000  6862         3          1        2      yes        no       NO
# 100  4830000  4815         2          1        1      yes        no       NO
#
# ...

# %%
house_features = house_features.sample(frac=1)

# %%
house_features
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 38  5523000   6900         3          1        1      yes       yes      YES
# 73  5040000  10700         3          1        2      yes       yes      YES
# 49  5285000   4600         2          2        1      yes        no       NO
# 15  5810000   4800         3          1        3      yes        no       NO
# 69  5110000   6100         3          1        1      yes        no      YES
# ..      ...    ...       ...        ...      ...      ...       ...      ...
# 20  5740000   5000         3          1        3      yes        no       NO
# 68  5110000  11410         2          1        2      yes        no       NO
# 84  4900000   4120         2          1        1      yes        no      YES
# 2   5950000   6540         3          1        1      yes       yes      YES
# 63  5215000   7200         3          1        2      yes       yes      YES
#
# ...

# %%
#Only select 20% data
house_features.sample(frac=0.1)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 85  4900000   5400         4          1        2      yes        no       NO
# 39  5495000   2817         4          2        2       no       yes      YES
# 50  5250000   4260         4          1        2      yes        no      YES
# 7   5943000  15600         3          1        1      yes        no       NO
# 55  5250000   5300         4          2        1      yes        no       NO
# 53  5250000  10269         3          1        1      yes        no       NO
# 92  4900000   4646         3          1        2      yes       yes      YES
# 12  5866000   4800         3          1        1      yes       yes      YES
# 28  5600000  10500         2          1        1      yes        no       NO
# 74  5040000   6600         3          1        1      yes       yes      YES
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# ...

# %%
house_features = house_features.drop('index', axis=1)

# %%
house_features = house_features.drop('level_0', axis=1)

# %%
house_features
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    5523000   6900         3          1        1      yes       yes      YES
# 1    5040000  10700         3          1        2      yes       yes      YES
# 2    5285000   4600         2          2        1      yes        no       NO
# 3    5810000   4800         3          1        3      yes        no       NO
# 4    5110000   6100         3          1        1      yes        no      YES
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 96   5740000   5000         3          1        3      yes        no       NO
# 97   5110000  11410         2          1        2      yes        no       NO
# 98   4900000   4120         2          1        1      yes        no      YES
# 99   5950000   6540         3          1        1      yes       yes      YES
# 100  5215000   7200         3          1        2      yes       yes      YES
#
# ...

# %%
house_features['price'] = house_features['price'].apply(lambda x: x/10)

# %%
house_features
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    552300.0   6900         3          1        1      yes       yes
# 1    504000.0  10700         3          1        2      yes       yes
# 2    528500.0   4600         2          2        1      yes        no
# 3    581000.0   4800         3          1        3      yes        no
# 4    511000.0   6100         3          1        1      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 96   574000.0   5000         3          1        3      yes        no
# 97   511000.0  11410         2          1        2      yes        no
# 98   490000.0   4120         2          1        1      yes        no
# 99   595000.0   6540         3          1        1      yes       yes
# 100  521500.0   7200         3          1        2      yes       yes
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...
